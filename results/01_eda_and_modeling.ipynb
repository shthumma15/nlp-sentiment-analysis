# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All imports successful!")
# Out:
# All imports successful!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:/Users/91630/OneDrive/Desktop/customer-churn-ml-project/data/telco_customer_churn.csv.csv')

df.shape
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
# columns to remove
drop_cols = [
    'CustomerID',
    'Count',
    'Country',
    'State',
    'City',
    'Zip Code',
    'Lat Long',
    'Latitude',
    'Longitude',
    'Churn Label',
    'Churn Score',
    'CLTV',
    'Churn Reason'
]

df_model = df.drop(columns=drop_cols)

# %%
df_model.shape
df_model.head()
# Out:
#    Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0    Male             No      No         No              2           Yes
# 1  Female             No      No        Yes              2           Yes
# 2  Female             No      No        Yes              8           Yes
# 3  Female             No     Yes        Yes             28           Yes
# 4    Male             No      No        Yes             49           Yes
#
#   Multiple Lines Internet Service Online Security Online Backup  \
# 0             No              DSL             Yes           Yes
# 1             No      Fiber optic              No            No
# 2            Yes      Fiber optic              No            No
# 3            Yes      Fiber optic              No            No
# 4            Yes      Fiber optic              No           Yes
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
df_model['Churn Value'].value_counts()
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
df_model['Churn Value'].value_counts(normalize=True) * 100
# Out:
# Churn Value
# 0    73.463013
# 1    26.536987
# Name: proportion, dtype: float64

# %%
sns.countplot(x='Churn Value', data=df_model)
plt.title('Churn Distribution')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Value', y='Tenure Months', data=df_model)
plt.title('Tenure vs Churn')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Contract', hue='Churn Value', data=df_model)
plt.title('Contract Type vs Churn')
plt.xticks(rotation=30)
plt.show()

# %%
X = df_model.drop('Churn Value', axis=1)
y = df_model['Churn Value']

# %%
categorical_cols = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

categorical_cols, numerical_cols
# Out:
# (Index(['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Phone Service',
#         'Multiple Lines', 'Internet Service', 'Online Security',
#         'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#         'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#         'Total Charges'],
#        dtype='object'),
#  Index(['Tenure Months', 'Monthly Charges'], dtype='object'))

# %%
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
)

# %%
X_train.shape
# Out:
# (5634, 6559)

# %%
X_test.shape
# Out:
# (1409, 6559)

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression(max_iter=1000)

log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = log_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8019872249822569
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87      1035
#            1       0.64      0.57      0.61       374
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.80      0.80      1409
#
#
# Confusion Matrix:
#
# [[915 120]
#  [159 215]]

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    class_weight='balanced'
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_rf))
print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Accuracy: 0.794889992902768
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1035
#            1       0.64      0.52      0.57       374
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.71      0.72      1409
# weighted avg       0.79      0.79      0.79      1409
#
#
# Confusion Matrix:
#
# [[925 110]
#  [179 195]]

# %%
feature_importance = pd.DataFrame({
    'Feature': X_encoded.columns,
    'Coefficient': log_model.coef_[0]
})

feature_importance['Absolute_Coefficient'] = feature_importance['Coefficient'].abs()

top_features = feature_importance.sort_values(
    by='Absolute_Coefficient', ascending=False
).head(10)

top_features
# Out:
#                            Feature  Coefficient  Absolute_Coefficient
# 5                   Dependents_Yes    -1.639286              1.639286
# 1637           Total Charges_20.15     1.456233              1.456233
# 1520            Total Charges_19.9     1.451270              1.451270
# 1644            Total Charges_20.5     1.397124              1.397124
# 24               Contract_Two year    -1.284786              1.284786
# 2516          Total Charges_288.05     1.249028              1.249028
# 9     Internet Service_Fiber optic     1.138229              1.138229
# 1636            Total Charges_20.1     1.137143              1.137143
# 1521           Total Charges_19.95     1.080875              1.080875
# 1514            Total Charges_19.6     1.080537              1.080537

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x='Churn Value', data=df_model)
plt.title('Churn Distribution')
plt.tight_layout()
plt.savefig('C:/Users/91630/OneDrive/Desktop/customer-churn-ml-project/Results/churn_distribution.png')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn Value', y='Tenure Months', data=df_model)
plt.title('Tenure vs Churn')
plt.tight_layout()
plt.savefig('C:/Users/91630/OneDrive/Desktop/customer-churn-ml-project/Results/tenure_vs_churn.png')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Contract', hue='Churn Value', data=df_model)
plt.title('Contract Type vs Churn')
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig('C:/Users/91630/OneDrive/Desktop/customer-churn-ml-project/Results/contract_vs_churn.png')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(
    x='Absolute_Coefficient',
    y='Feature',
    data=top_features
)
plt.title('Top Features Influencing Churn')
plt.tight_layout()
plt.savefig('C:/Users/91630/OneDrive/Desktop/customer-churn-ml-project/Results/top_features.png')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import joblib

# Select important features for demo
demo_features = df_model[['Tenure Months', 'Monthly Charges', 'Churn Value']]

X_demo = demo_features[['Tenure Months', 'Monthly Charges']]
y_demo = demo_features['Churn Value']

X_train_d, X_test_d, y_train_d, y_test_d = train_test_split(
    X_demo, y_demo, test_size=0.2, random_state=42, stratify=y_demo
)

demo_model = LogisticRegression()
demo_model.fit(X_train_d, y_train_d)

# Save model
joblib.dump(demo_model, 'demo_churn_model.pkl')
# Out:
# ['demo_churn_model.pkl']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import joblib

# Use simple demo features
demo_features = df_model[['Tenure Months', 'Monthly Charges', 'Churn Value']]

X_demo = demo_features[['Tenure Months', 'Monthly Charges']]
y_demo = demo_features['Churn Value']

X_train_d, X_test_d, y_train_d, y_test_d = train_test_split(
    X_demo, y_demo, test_size=0.2, random_state=42, stratify=y_demo
)

demo_model = LogisticRegression()
demo_model.fit(X_train_d, y_train_d)

# SAVE MODEL IN PROJECT ROOT
joblib.dump(demo_model, 'C:/Users/91630/OneDrive/Desktop/customer-churn-ml-project/demo_churn_model.pkl')
# Out:
# ['C:/Users/91630/OneDrive/Desktop/customer-churn-ml-project/demo_churn_model.pkl']
